# %%
import h5py
import matplotlib.pyplot as plt
from os import listdir
from mpl_toolkits import mplot3d

files = listdir('data/organic')
count = 0

for file in files:

    #file = 'star_particles_015_z002p012.hdf5'
    f = h5py.File('data/organic/' + file,'r')

    #list(f.keys())
    
    ds_c = f['Coordinates']

    #ds_m = f['Mass']
    #ds_m.shape

    #print(ds_c[0:34])
    #print('-------')
    #print(ds_c[0:,0])

    print (file)

    fig = plt.figure(figsize = (6,8))
    ax = plt.subplots(2)
    
    ax=plt.axes(projection = '3d')
    ax.scatter(ds_c[0:,0], ds_c[0:,1], ds_c[0:,2])
    ax.axes.set_xlim3d(left=-0.03, right=0.03) 
    ax.axes.set_ylim3d(bottom=-0.03, top=0.03) 
    ax.axes.set_zlim3d(bottom=-0.03, top=0.03) 
    plt.savefig('3d\\plot' + str(count) + '.png', dpi=300)
    plt.show()
    
    count = count + 1
    
    # ffmpeg -framerate 2 -i plot%d.png organic.mp4
# Out:
# star_particles_005_z007p050.hdf5
# star_particles_006_z005p971.hdf5
# star_particles_007_z005p487.hdf5
# star_particles_008_z005p037.hdf5
# star_particles_009_z004p485.hdf5
# star_particles_010_z003p984.hdf5
# star_particles_011_z003p528.hdf5
# star_particles_012_z003p017.hdf5
# star_particles_013_z002p478.hdf5
# star_particles_014_z002p237.hdf5
# star_particles_015_z002p012.hdf5
# star_particles_016_z001p737.hdf5
# star_particles_017_z001p487.hdf5
# star_particles_018_z001p259.hdf5
# star_particles_019_z001p004.hdf5
# star_particles_020_z000p865.hdf5
# star_particles_021_z000p736.hdf5
# star_particles_022_z000p615.hdf5
# star_particles_023_z000p503.hdf5
# star_particles_024_z000p366.hdf5
# star_particles_025_z000p271.hdf5
# star_particles_026_z000p183.hdf5
# star_particles_027_z000p101.hdf5
# star_particles_028_z000p000.hdf5
